# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv('marketing_campaign_data(1).csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv('marketing_campaign_data(1).csv')
#       2 df.head()
#
# File ~\Documents\GitHub\EDA\vrenv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv('sales_200_records.csv')
df.head()
# Out:
#    Order_ID  Order_Date  Product Region  Quantity  Unit_Price  Total_Sales
# 0         1  2025-12-17  Monitor  South         1       27152        27152
# 1         2  2025-01-22   Tablet  North         1         534          534
# 2         3  2025-08-14   Tablet  South         8       34074       272592
# 3         4  2025-12-29   Laptop   East         3       39207       117621
# 4         5  2025-05-28   Laptop  North         4       44706       178824

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     200 non-null    int64
#  1   Order_Date   200 non-null    object
#  2   Product      200 non-null    object
#  3   Region       200 non-null    object
#  4   Quantity     200 non-null    int64
#  5   Unit_Price   200 non-null    int64
#  6   Total_Sales  200 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 11.1+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID       0
# Order_Date     0
# Product        0
# Region         0
# Quantity       0
# Unit_Price     0
# Total_Sales    0
# dtype: int64

# %%
df.describe()
# Out:
#          Order_ID    Quantity    Unit_Price   Total_Sales
# count  200.000000  200.000000    200.000000     200.00000
# mean   100.500000    5.615000  23598.325000  130586.41000
# std     57.879185    2.880671  14172.393462  112830.43287
# min      1.000000    1.000000    534.000000     534.00000
# 25%     50.750000    3.000000  11594.250000   33960.00000
# 50%    100.500000    6.000000  24469.500000   97752.00000
# 75%    150.250000    8.000000  33832.500000  190957.50000
# max    200.000000   10.000000  49556.000000  495560.00000

# %%
df.shape
# Out:
# (200, 7)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Product', 'Region', 'Quantity', 'Unit_Price',
#        'Total_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID        int64
# Order_Date     object
# Product        object
# Region         object
# Quantity        int64
# Unit_Price      int64
# Total_Sales     int64
# dtype: object

# %%
df_healthcare = pd.read_csv('healthcare_patient_data.csv')
df_healthcare
# Out:
#      PatientID           Name   Age  Gender      Diagnosis  TreatmentCost  \
# 0         3001     Iris Jones  60.0  Female  Heart Disease       18030.76
# 1         3002    Henry Smith  61.0    Male  Heart Disease       21824.92
# 2         3003      Bob Davis  74.0  Female      Pneumonia            NaN
# 3         3004     Iris Brown  42.0    Male   Hypertension       43709.32
# 4         3005  Henry Johnson  66.0    Male       Migraine       14013.19
# ..         ...            ...   ...     ...            ...            ...
# 403       3397   David Miller  55.0  Female       COVID-19       43912.05
# 404       3398    David Jones  32.0  Female      Arthritis        7436.19
# 405       3399   Eve Williams   NaN  Female      Allergies       46873.14
# 406       3400  Jack Williams  48.0  Female      Pneumonia       26811.87
# 407       3400  Jack Williams  48.0  Female      Pneumonia       26811.87
#
#     AdmissionDate DischargeDate    Outcome InsuranceProvider
# ...

# %%
df_healthcare.head()
# Out:
#    PatientID           Name   Age  Gender      Diagnosis  TreatmentCost  \
# 0       3001     Iris Jones  60.0  Female  Heart Disease       18030.76
# 1       3002    Henry Smith  61.0    Male  Heart Disease       21824.92
# 2       3003      Bob Davis  74.0  Female      Pneumonia            NaN
# 3       3004     Iris Brown  42.0    Male   Hypertension       43709.32
# 4       3005  Henry Johnson  66.0    Male       Migraine       14013.19
#
#   AdmissionDate DischargeDate    Outcome InsuranceProvider
# 0    2024-03-09    2024-03-17  Recovered             Aetna
# 1    2024-08-26    2024-09-08     Stable               NaN
# 2    2024-12-25    2025-01-06   Improved        Blue Cross
# 3    2024-05-07    2024-05-15   Improved             Aetna
# 4    2024-10-26    2024-10-31     Stable             Cigna

# %%
df_healthcare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PatientID          408 non-null    int64
#  1   Name               408 non-null    object
#  2   Age                379 non-null    float64
#  3   Gender             408 non-null    object
#  4   Diagnosis          408 non-null    object
#  5   TreatmentCost      361 non-null    float64
#  6   AdmissionDate      408 non-null    object
#  7   DischargeDate      408 non-null    object
#  8   Outcome            408 non-null    object
#  9   InsuranceProvider  338 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 32.0+ KB
